# %%
import pandas as pd
from urllib import request

# %% [markdown]
# ### Getting the dataset

# %%
data = request.urlopen("https://storage.googleapis.com/maps-premium/dataset/yes_complete/train.txt")

# %% [markdown]
# ### Parsing the HTTP response

# %%
lines = data.read().decode("utf-8").split('\n')

# %% [markdown]
# ### Splitting the songs id (remove playlists with one song)

# %%
playlists = [line.rstrip().split() for line in lines if len(line.split()) > 1]

# %% [markdown]
# ### Load song metadata

# %%
metadata = request.urlopen("https://storage.googleapis.com/maps-premium/dataset/yes_complete/song_hash.txt")

# %% [markdown]
# ### Parsing the HTTP response

# %%
metadata_lines = metadata.read().decode("utf-8").split('\n')

# %% [markdown]
# ### Splitting the songs metadata

# %%
songs = [s.rstrip().split('\t') for s in metadata_lines]

# %%
songs
# Out:
# [['0 ', 'Gucci Time (w\\/ Swizz Beatz)', 'Gucci Mane'],
#  ['1 ', 'Aston Martin Music (w\\/ Drake & Chrisette Michelle)', 'Rick Ross'],
#  ['2 ', 'Get Back Up (w\\/ Chris Brown)', 'T.I.'],
#  ['3 ', 'Hot Toddy (w\\/ Jay-Z & Ester Dean)', 'Usher'],
#  ['4 ', 'Whip My Hair', 'Willow'],
#  ['5 ', 'Down On Me (w\\/ 50 Cent)', 'Jeremih'],
#  ['6 ', 'Black And Yellow', 'Wiz Khalifa'],
#  ['7 ', 'Blowing Me Kisses', 'Soulja Boy'],
#  ['8 ', 'Lay It Down', 'Lloyd'],
#  ['9 ', 'Good For My Money (w\\/ Lloyd)', 'Baby Bash'],
#  ['10 ', 'Shake It', 'Elephant Man'],
#  ['11 ', 'My Cupp', 'Richie Loop'],
#  ['12 ', "Who's That Chick", 'Rihanna'],
#  ['13 ', 'Like A G6 (w\\/ The Cataracs & Dec)', 'Far East Movement'],
#  ['14 ', "DJ Got Us Fallin' In Love (w\\/ Pitbull)", 'Usher'],
#  ['15 ', 'Hurt Me Soul', 'Lupe Fiasco'],
#  ['16 ', 'Put It In A Love Song (w\\/ Beyonce)', 'Alicia Keys'],
#  ['17 ', 'All I Wants Is You (w\\/ J Cole)', 'Miguel'],
#  ['18 ', 'Champagne Life', 'Ne-Yo'],
#  ['19 ', 'Find Your Love', 'Drake'],
#  ['20 ', 'Your Love', 'Nicki Minaj'],
#  ['21 ', 'Do For Love', '2Pac'],
#  ['22 ', "Doin' It", 'LL Cool J'],
#  ['23 ', 'Ms. Jackson', 'Outkast'],
#  ['24 ', 'Close To You', 'Maxi Priest'],
#  ['25 ', 'Right Thru Me', 'Nicki Minaj'],
#  ['26 ', 'Hands On Me', 'Bobby Valentino'],
#  ['27 ', 'Try Sleeping With A Broken Heart', 'Alicia Keys'],
#  ['28 ', 'I Need A Girl', 'Trey Songz'],
#  ['29 ', 'Broken-Hearted Girl', 'Beyonce'],
#  ['30 ', 'Go On Girl', 'Ne-Yo'],
#  ['31 ', 'Need A Boss (w\\/ Ludacris)', 'Shareefa'],
#  ['32 ', 'You Make Me Wanna...', 'Usher'],
#  ['33 ', 'Last Night', 'Az Yet'],
#  ['34 ', 'That Day Will Come', 'Capleton'],
#  ['35 ', 'That Ghetto Girl', 'Richie Spice'],
#  ['36 ', 'Living In Love', 'I Wayne'],
#  ['37 ', 'By His Deeds', 'VC'],
#  ['38 ', 'Cleanin Out My Closet', 'Eminem'],
#  ['39 ', 'Always', 'Jason Champion'],
#  ['40 ', 'No Looking Back', 'Damita'],
#  ['41 ', 'Get Busy', 'Sean Paul'],
#  ['42 ', 'Lost Ones', 'Lauryn Hill'],
#  ['43 ', 'I Get Crazy (w\\/ Lil Wayne)', 'Nicki Minaj'],
#  ['44 ', 'Nothing To Smile About', 'Morgan Heritage'],
#  ['45 ', 'Mi Caan Sleep', 'Romain Virgo'],
#  ['46 ', "What's My Name (w\\/ Drake)", 'Rihanna'],
#  ['47 ', 'One In A Million', 'Ne-Yo'],
#  ['48 ', 'Check It Out (w\\/ Nicki Minaj)', 'Will.I.Am'],
#  ['49 ', 'Be Without You', 'Mary J. Blige'],
#  ['50 ', 'Bottoms Up (w\\/ Nicki Minaj)', 'Trey Songz'],
#  ['51 ', 'There Goes My Baby', 'Usher'],
#  ['52 ', "Sittin' Up In My Room", 'Brandy'],
#  ['53 ', 'Up All Night (w\\/ Nicki Minaj)', 'Drake'],
#  ['54 ', "We're Not Making Love No More", 'Dru Hill'],
#  ['55 ', "I Wish I Wasn't", 'Heather Headley'],
#  ['56 ', 'One Last Cry', 'Brian McKnight'],
#  ['57 ', 'Liquor Store Blues (w\\/ Damian Marley)', 'Bruno Mars'],
#  ['58 ', 'Love Is Blind', 'Eve'],
#  ['59 ',
#   'Monster (w\\/ Rick Ross, Jay-Z, Nicki Minaj & Bon Iver)',
#   'Kanye West'],
#  ['60 ', 'Just The Way You Are', 'Bruno Mars'],
#  ['61 ', 'On My Mind', "Da'Ville"],
#  ['62 ', 'Runaway (w\\/ Pusha T)', 'Kanye West'],
#  ['63 ', 'Love The Way You Lie (w\\/ Rihanna)', 'Eminem'],
#  ['64 ', 'Neighbors Know My Name', 'Trey Songz'],
#  ['65 ', 'You Know What It Is (w\\/ Wyclef Jean)', 'T.I.'],
#  ['66 ', 'Everything', 'Mary J. Blige'],
#  ['67 ', 'Girls All Around The World (w\\/ Lil Wayne)', 'Lloyd'],
#  ['68 ', 'Boom Boom Pow', 'Black Eyed Peas'],
#  ['69 ', "Holding You Down (Goin' In Circles)", 'Jazmine Sullivan'],
#  ['70 ', 'Deuces', 'Chris Brown & Tyga'],
#  ['71 ',
#   'All I Do Is Win (w\\/ T-Pain, Ludacris, Rick Ross & Snoop Dogg)',
#   'DJ Khaled'],
#  ['72 ', 'Roger That', 'Young Money'],
#  ['73 ', 'Knockout (w\\/ Nicki Minaj)', 'Lil Wayne'],
#  ['74 ', 'Letting Go (Dutty Love) (w\\/ Nicki Minaj)', 'Sean Kingston'],
#  ['75 ', 'Hello, Good Morning (w\\/ T.I.)', 'Diddy & Dirty Money'],
#  ['76 ', 'Get It All (w\\/ Nicki Minaj)', 'Sean Garrett'],
#  ['77 ', 'You Be Killin Em', 'Fabolous'],
#  ['78 ', 'Soca Bhangra', 'Bunji Garlin'],
#  ['79 ', 'Fettin On (w\\/ Machel Montano)', 'Skinny Fabulous'],
#  ['80 ', 'Ants In Yuh Sugar Pan', 'Jamesy P'],
#  ['81 ', 'Fancy (w\\/ T.I. & Swizz Beatz)', 'Drake'],
#  ['82 ', 'Only Girl (In The World)', 'Rihanna'],
#  ['83 ', 'California Gurls', 'Katy Perry'],
#  ['84 ', 'Latest News', 'Mr. Vegas'],
#  ['85 ', 'Dynamite', 'Taio Cruz'],
#  ['86 ', 'Break Your Heart (w\\/ Ludacris)', 'Taio Cruz'],
#  ['87 ', 'Baby (w\\/ Ludacris)', 'Justin Bieber'],
#  ['88 ', 'OMG (w\\/ Will.I.Am)', 'Usher'],
#  ['89 ', 'Hard (w\\/ Young Jeezy)', 'Rihanna'],
#  ['90 ', 'Yeah 3X', 'Chris Brown'],
#  ['91 ', 'Together Again', 'Janet Jackson'],
#  ['92 ', 'Somebody To Love', 'Justin Bieber'],
#  ['93 ', 'Rockstar 101 (w\\/ Slash)', 'Rihanna'],
#  ['94 ', 'I Like (w\\/ Ludacris)', 'Jeremih'],
#  ['95 ', 'I Know (w\\/ Pharrell)', 'Jay-Z'],
#  ['96 ', 'Airplanes (w\\/ Hayley Williams)', 'B.o.B'],
#  ['97 ', 'Crawl', 'Chris Brown'],
#  ['98 ', 'Successful (w\\/ Trey Songz)', 'Drake'],
#  ['99 ', 'Everything, Everyday, Everywhere (w\\/ Keri Hilson)', 'Fabolous'],
#  ['100 ', "I'm Yours", 'Jason Mraz'],
#  ['101 ', 'Fireflies', 'Owl City'],
#  ['102 ', 'Blame It (w\\/ T-Pain)', 'Jamie Foxx'],
#  ['103 ', 'The One (w\\/ Drake)', 'Mary J. Blige'],
#  ['104 ', "As Long As There's You", 'The McClurkin Project'],
#  ['105 ', 'Grace', 'BeBe & CeCe Winans'],
#  ['106 ', 'Fragile Heart', 'Yolanda Adams'],
#  ['107 ', 'Golden', 'Jill Scott'],
#  ['108 ', '#1 Thing', 'Amerie'],
#  ['109 ', 'Be OK (w\\/ Will.I.Am)', 'Chrisette Michele'],
#  ['110 ', 'Johnny Was', 'Bob Marley & The Wailers'],
#  ['111 ', "Un-Thinkable (I'm Ready)", 'Alicia Keys'],
#  ['112 ', 'Soldier Of Love', 'Sade'],
#  ['113 ',
#   'Wake Up Everybody (w\\/ Common & Melanie Fiona)',
#   'John Legend & The Roots'],
#  ['114 ', 'Father Of Soca', 'Isaac Blackman'],
#  ['115 ', "Chippin' (With Me Own Woman)", 'Farmer Nappy'],
#  ['116 ', 'Macoing', 'Silver'],
#  ['117 ', 'Wrong House', 'Ninja'],
#  ['118 ', 'Nikita', 'Scrunter'],
#  ['119 ', 'The Cork', 'Kenny J'],
#  ['120 ', 'Lifting Up The Name Of Jesus', 'Helen Baylor'],
#  ['121 ', 'Stomp', "God's Property"],
#  ['122 ', 'Praise Ye Jah', 'Sizzla'],
#  ['123 ', 'Hills And Valleys', 'Buju Banton'],
#  ['124 ', 'Single Ladies (Put A Ring On It)', 'Beyonce'],
#  ['125 ', 'We Belong Together', 'Mariah Carey'],
#  ['126 ', 'My Chick Bad (w\\/ Nicki Minaj)', 'Ludacris'],
#  ['127 ', 'Pavement (w\\/ Kerwin Dubois)', 'Farmer Nappy'],
#  ['128 ', 'Me No Play', 'Swappi'],
#  ['129 ', 'All The Above (w\\/ T-Pain)', 'Maino'],
#  ['130 ', 'Neva Scared', 'Vybz Kartel'],
#  ['131 ', 'Bella', 'Drop The Lime'],
#  ['132 ', 'Oil In The Coil', 'Scrunter'],
#  ['133 ', 'Golo', 'Second Imij'],
#  ['134 ', 'Mr Bissessar', 'Drupatee'],
#  ['135 ', 'Curry Tabanca', 'Mighty Trini'],
#  ['136 ', 'Happy', 'Shandileer'],
#  ['137 ', 'Betty Goaty', 'Penguin'],
#  ['138 ', 'Died In Your Arms', 'Smitty'],
#  ['139 ', 'Clarks (w\\/ Popcaan & Gaza Slim)', 'Vybz Kartel'],
#  ['140 ', 'Hold Yuh', 'Gyptian'],
#  ['141 ', 'Love Me Have Fi Get', 'Cutty Ranks & Beres Hammond'],
#  ['142 ', 'Dying (w\\/ Serani)', 'Mavado'],
#  ['143 ', 'Doh (w\\/ Bugle)', 'Serani'],
#  ['144 ', 'Try Offa Yuh', 'Buju Banton'],
#  ['145 ', 'Send It On', 'Busy Signal'],
#  ['146 ', 'Lil Freak (w\\/ Nicki Minaj)', 'Usher'],
#  ['147 ', 'Massive Attack (w\\/ Sean Garrett)', 'Nicki Minaj'],
#  ['148 ', 'Kimbo King', 'Reggie Stepper'],
#  ['149 ', 'Sweetness', 'Beres Hammond'],
#  ['150 ', 'Make It Like It Was', 'Regina Belle'],
#  ['151 ', 'Just Be A Man About It (w\\/ Dr. Dre)', 'Toni Braxton'],
#  ['152 ', 'Walked Outta Heaven', 'Jagged Edge'],
#  ['153 ', "Don't Wanna Try\\/Ya No Es Igual", 'Frankie J'],
#  ['154 ', 'Maybe I Deserve', 'Tank'],
#  ['155 ', "Not Gon' Cry", 'Mary J. Blige'],
#  ['156 ', 'Love', 'Keyshia Cole'],
#  ['157 ', 'Sweet Lady', 'Tyrese'],
#  ['158 ', "All The Things (Your Man Won't Do)", 'Joe'],
#  ['159 ', 'End Of The Road', 'Boyz II Men'],
#  ['160 ', 'Stranger In My House', 'Tamia'],
#  ['161 ', 'My First Love (w\\/ Ketara Wyatt)', 'Avant'],
#  ['162 ', 'Diary (w\\/ Tony! Toni! Tone!)', 'Alicia Keys'],
#  ['163 ', 'Bed', 'J. Holiday'],
#  ['164 ', 'Last Time', 'Trey Songz'],
#  ['165 ', 'Stroke You Up', 'Changing Faces'],
#  ['166 ', 'Freak Me', 'Silk'],
#  ['167 ', 'Turn Your Lights Down Low', 'Bob Marley & Lauryn Hill'],
#  ['168 ', 'All My Life', 'K-Ci & JoJo'],
#  ['169 ', 'U Got It Bad ', 'Usher'],
#  ['170 ', 'Emotion', "Destiny's Child"],
#  ['171 ', 'Birthday Sex', 'Jeremih'],
#  ['172 ', 'Signs Of Love Makin', 'Tyrese'],
#  ['173 ', 'I Care 4 U', 'Aaliyah'],
#  ['174 ', 'For You I Will', 'Monica'],
#  ['175 ', "If This Isn't Love", 'Jennifer Hudson'],
#  ['176 ', 'Water Runs Dry', 'Boyz II Men'],
#  ['177 ', "Like You'll Never See Me Again", 'Alicia Keys'],
#  ['178 ', 'Halo', 'Beyonce'],
#  ['179 ', 'Destiny', 'Buju Banton'],
#  ['180 ', 'Beware', 'Tarrus Riley'],
#  ['181 ', 'August Town', 'Duane Stephenson'],
#  ['182 ', 'Murderer', 'Barrington Levy'],
#  ['183 ', 'Wanna Be Loved', 'Buju Banton'],
#  ['184 ', "Don't Haffi Dread", 'Morgan Heritage'],
#  ['185 ', 'These Are The Days', 'Busy Signal'],
#  ['186 ', 'Get In My Car', '50 Cent'],
#  ['187 ', 'Hard Knock Life (Ghetto Anthem)', 'Jay-Z'],
#  ['188 ', 'Who Feels It Knows It', 'Romain Virgo'],
#  ['189 ', "Can't Satisfy Her", 'I Wayne'],
#  ['190 ', 'Gangster Love', 'Bounty Killer'],
#  ['191 ', 'What Will It Take', 'Jah Cure'],
#  ['192 ', 'Nothing On You (w\\/ Bruno Mars)', 'B.o.B.'],
#  ['193 ', 'How Many Licks (w\\/ Sisqo)', "Lil' Kim"],
#  ['194 ', "Yeah (w\\/ Lil' Jon & Ludacris)", 'Usher'],
#  ['195 ', 'Numb\\/Encore', 'Jay-Z & Linkin Park'],
#  ['196 ', "I'll Be Missing You", 'Puff Daddy & The Family'],
#  ['197 ', 'Changes', '2Pac'],
#  ['198 ', 'Sensemelia Persecution', 'Buju Banton'],
#  ['199 ', 'No Matter What', 'T.I.'],
#  ['200 ', 'Truth Is', 'Fantasia'],
#  ['201 ', "I'll Make Love To You", 'Boyz II Men'],
#  ['202 ', 'One Away', 'Sizzla'],
#  ['203 ', 'Raggy Road', 'Capleton'],
#  ['204 ', 'No Disturb Sign', 'Beres Hammond'],
#  ['205 ', "She's Royal", 'Tarrus Riley'],
#  ['206 ', 'Brown Skin', 'Richie Spice'],
#  ['207 ', "Same Ol' G", 'Ginuwine'],
#  ['208 ', 'My Love Is Your Love', 'Whitney Houston'],
#  ['209 ', "Can't Be Friends", 'Trey Songz'],
#  ['210 ', 'Already Taken', 'Trey Songz'],
#  ['211 ', 'Hypnotize', 'The Notorious B.I.G.'],
#  ['212 ', 'Southern Hospitality (w\\/ Pharrell)', 'Ludacris'],
#  ['213 ', "I'm Ill (w\\/ Fabolous)", 'Red Cafe'],
#  ['214 ', 'Dwayne', 'Red Rat'],
#  ['215 ', 'Everyone Falls In Love', 'Tanto Metro & Devonte'],
#  ['216 ', "Blowin' Money Fast (B.M.F.) (w\\/ Styles P)", 'Rick Ross'],
#  ['217 ', 'Whatcha Say', 'Jason DeRulo'],
#  ['218 ', "Ridin' Solo", 'Jason DeRulo'],
#  ['219 ', 'I Was Born A Winner', 'Freddie McGregor'],
#  ['220 ', 'My Time', 'Barrington Levy'],
#  ['221 ', "Doctor's Orders", 'Beres Hammond'],
#  ['222 ', "Frontin' (w\\/ Jay-Z)", 'Pharrell'],
#  ['223 ', "Game's Pain (w\\/ Keyshia Cole)", 'The Game'],
#  ['224 ', 'Chutkaipan', 'Scrunter'],
#  ['225 ', 'Say Aah', 'Trey Songz'],
#  ['226 ', 'Woo Hah!! Got You All In Check', 'Busta Rhymes'],
#  ['227 ', 'Shimmy Shimmy Ya', "Ol' Dirty Bastard"],
#  ['228 ', 'Get At Me Dog (w\\/ Sheek Louch)', 'DMX'],
#  ['229 ', 'Get Your Money Up (w\\/ Keyshia Cole & Trina)', 'Keri Hilson'],
#  ['230 ', 'U A Mi Baby', 'Vybz Kartel'],
#  ['231 ', 'Bike Back', 'Black Ryno'],
#  ['232 ', 'Bill', 'Gaza Kim & Lisa Hype'],
#  ['233 ', "Club Can't Handle Me (w\\/ David Guetta)", 'Flo-Rida'],
#  ['234 ', 'Pon De Floor (w\\/ Vybz Kartel)', 'Major Lazer'],
#  ['235 ', 'Daggering', 'Mr. Vegas'],
#  ['236 ', 'Gyal Bend Ova', 'Mavado'],
#  ['237 ', 'Tusty (w\\/ Blaxx)', 'Roy Cape'],
#  ['238 ', 'Jumpie', 'Blazer Dan'],
#  ['239 ', 'Body Good (w\\/ Iyaka)', 'Beenie Man'],
#  ['240 ', 'Keep Your Friendship', 'Mr. Vegas'],
#  ['241 ', 'Nah Let Go', 'Gyptian'],
#  ['242 ', 'Right Above It (w\\/ Drake)', 'Lil Wayne'],
#  ['243 ', 'What Dem A Say', 'Mavado'],
#  ['244 ', 'All Out', 'Sean Paul'],
#  ['245 ', 'Reverse Di Ting', 'Beenie Man'],
#  ['246 ', 'Billionaire (w\\/ Bruno Mars)', 'Travie McCoy'],
#  ['247 ', 'Waistline', 'Buju Banton'],
#  ['248 ', 'Not Going Down', 'Busy Signal'],
#  ['249 ', 'Willie Bounce', 'Elephant Man'],
#  ['250 ', 'Hot Wuk (w\\/ Hotaball & Opal)', 'Mr. Vegas'],
#  ['251 ', 'Tek Weh Yuh Self', 'Mr. Vegas'],
#  ['252 ', 'Hi Grade', 'Busy Signal'],
#  ['253 ', 'Ring The Alarm', 'Tenor Saw'],
#  ['254 ', 'Light Up (w\\/ Jay-Z)', 'Drake'],
#  ['255 ', '2010', 'Jah Cure'],
#  ['256 ', 'Below The Waist', 'Queen Ifrica'],
#  ['257 ', 'Chakka Dance', 'Beenie Man'],
#  ['258 ', 'Wacky Dip (w\\/ Ding Dong)', 'Voicemail'],
#  ['259 ', 'Hunting', 'Blaxx'],
#  ['260 ', 'No Behaviour', 'Machel Montano'],
#  ['261 ', "Won't Stop", 'Machel Montano'],
#  ['262 ', 'Congo Man', 'Machel Montano'],
#  ['263 ', 'Fete', 'Bunji Garlin'],
#  ['264 ', 'Drop The World (w\\/ Eminem)', 'Lil Wayne'],
#  ['265 ', 'Tight Up Skirt', 'Red Rat'],
#  ['266 ', 'Chi Chi Man', 'T.O.K.'],
#  ['267 ', 'Venus Vs. Mars', 'Jay-Z'],
#  ['268 ', "We Thuggin' (w\\/ R. Kelly)", 'Fat Joe'],
#  ['269 ', 'Put Your Hands Where My Eyes Could See', 'Busta Rhymes'],
#  ['270 ', 'Dangerous', 'Busta Rhymes'],
#  ['271 ', 'The Template', 'Super Jigga Tc'],
#  ['272 ', 'Mad Carnival', 'Bunji Garlin'],
#  ['273 ', 'Pipe', 'Patch'],
#  ['274 ', 'Tic Toc', 'Dawg-E-Slaughter'],
#  ['275 ', 'Just You And I', 'Ricky Blaze'],
#  ['276 ', 'My Money (Ha Ha)', 'Merital'],
#  ['277 ', 'Forever (w\\/ Kanye West, Eminem & Lil Wayne)', 'Drake'],
#  ['278 ', 'Always Strapped (w\\/ Lil Wayne)', 'Birdman'],
#  ['279 ', 'Deh Pon The Scene', 'Mr. Vegas'],
#  ['280 ', 'We Grow', 'Serani'],
#  ['281 ', 'Gallis', 'Mr. Vegas'],
#  ['282 ', 'Hope And Pray', 'Mavado'],
#  ['283 ', 'Real Killa (No Chorus)', 'Mavado'],
#  ['284 ', 'Weh Dem A Go', 'Vybz Kartel & Jahvinci'],
#  ['285 ', 'Mek She Stamma', 'Busy Signal'],
#  ['286 ', 'Bumper To Fender', 'Machel Montano'],
#  ['287 ', 'Push Push (w\\/ Akon)', 'Kat DeLuna'],
#  ['288 ', 'Hey Baby (Drop It To The Floor) (w\\/ T-Pain)', 'Pitbull'],
#  ['289 ', 'Wine U A Wine', "Da'Ville"],
#  ['290 ', 'Back It Up', 'Rayvon'],
#  ['291 ', 'No Love (w\\/ Lil Wayne)', 'Eminem'],
#  ['292 ', 'No Hands (w\\/ Roscoe Dash & Wale)', 'Waka Flocka Flame'],
#  ['293 ', 'Silver And Gold', 'Luciano'],
#  ['294 ', 'Give I Strength (w\\/ Ras Shiloh)', 'Buju Banton'],
#  ['295 ', 'Dreams', 'The Game'],
#  ['296 ', 'Shawty (w\\/ T-Pain)', 'Plies'],
#  ['297 ', 'Heaven Sent', 'Keyshia Cole'],
#  ['298 ', 'We Ride', 'Rihanna'],
#  ['299 ', 'Unconditional Love (w\\/ Phyllisia)', 'Jah Cure'],
#  ['300 ', 'Fallen Soldiers', 'Demarco'],
#  ['301 ', 'I Believe', 'Sounds Of Blackness'],
#  ['302 ', 'Hanging On', 'Britt Nicole'],
#  ['303 ', 'Keep It To Yourself', 'Queen Ifrica'],
#  ['304 ', 'Miles Away', 'Jah Cure'],
#  ['305 ', 'Feel Good', 'Beres Hammond'],
#  ['306 ', 'Call On Me (w\\/ Phyllisia)', 'Jah Cure'],
#  ['307 ', 'Super High (w\\/ Ne-Yo)', 'Rick Ross'],
#  ['308 ', 'World Dance', 'Beenie Man'],
#  ['309 ', 'Fowl Affair', 'Silver Cat'],
#  ['310 ', 'Toro Toro', 'Horyzon'],
#  ['311 ', 'Over', 'Drake'],
#  ['312 ', 'Ghetto Story', 'Cham'],
#  ['313 ', 'All Over De Gyal', 'Lyrikal'],
#  ['314 ', 'Hero (w\\/ Keri Hilson)', 'Nas'],
#  ['315 ', 'Wild Ants', 'Machel Montano'],
#  ['316 ', 'Cyaa Friend Again', 'Di Genius'],
#  ['317 ', 'Study People', 'Serani'],
#  ['318 ', 'Click Mi Finger', 'Erup'],
#  ['319 ', "Can't Tell Me Nothing", 'Kanye West'],
#  ['320 ', "This Is Why I'm Hot", 'MIMS'],
#  ['321 ', 'Candy Shop (w\\/ Olivia)', '50 Cent'],
#  ['322 ', 'Hands Up (w\\/ 50 Cent)', 'Lloyd Banks'],
#  ['323 ', 'Million Bucks (w\\/ Swizz Beatz)', 'Maino'],
#  ['324 ', "Quiet Storm (w\\/ Lil' Kim)", 'Mobb Deep'],
#  ['325 ', 'Back It Up', 'Beenie Man'],
#  ['326 ', "Jockin' Jay-Z (Dope Boy Fresh)", 'Jay-Z'],
#  ['327 ', 'Rider, Part 2', 'G-Unit'],
#  ['328 ', 'Ride The Wave', 'Trav'],
#  ['329 ', 'Stronger', 'Kanye West'],
#  ['330 ', 'Hate It Or Love It (w\\/ 50 Cent)', 'The Game'],
#  ['331 ', 'Get Low (w\\/ Ying Yang Twins)', "Lil' Jon & The Eastside Boyz"],
#  ['332 ', 'Money In The Bank', 'Swizz Beatz'],
#  ['333 ', "Hit 'Em Up (w\\/ The Outlawz)", '2Pac'],
#  ['334 ', 'Real Situation', 'Bob Marley & The Wailers'],
#  ['335 ', 'Chase The Devil', 'Max Romeo And The Upsetters'],
#  ['336 ', 'Ghetto People Song', 'Everton Blender'],
#  ['337 ', 'Herbman Hustling', 'Sugar Minott'],
#  ['338 ', 'Pass The Dutchie', 'Musical Youth'],
#  ['339 ', 'One Step Forward', 'Max Romeo'],
#  ['340 ', "It's Me Again Jah", 'Luciano'],
#  ['341 ', 'Gone Already', 'Faith Evans'],
#  ['342 ', 'Miss You', 'Aaliyah'],
#  ['343 ', "I'm Sprung", 'T-Pain'],
#  ['344 ', 'Pretty Girl Rock', 'Keri Hilson'],
#  ['345 ', 'Ride (w\\/ Ludacris)', 'Ciara'],
#  ['346 ', 'She Got It (w\\/ T-Pain & Tay Dizm)', '2 Pistols'],
#  ['347 ', 'Love Is My Disease', 'Alicia Keys'],
#  ['348 ', 'Stereo Love (w\\/ Vika Jigulina)', 'Edward Maya'],
#  ['349 ', 'Godspot', 'The Anointed'],
#  ['350 ', "It's Raining", 'Deitrick Haddon'],
#  ['351 ', 'Never Find', 'Jah Cure'],
#  ['352 ', "I Ain't Mad At Cha (w\\/ Danny Boy)", '2Pac'],
#  ['353 ', 'Spellwork', 'Austra'],
#  ['354 ', 'Haffi Get De Gal Ya (Hot Gal Today) (w\\/ Mr. Vegas)', 'Sean Paul'],
#  ['355 ', 'Licks', 'Bunji Garlin'],
#  ['356 ', 'Ur So Gay', 'Katy Perry'],
#  ['357 ', 'Ready Fi Di Ride', 'Shaggy'],
#  ['358 ', 'I Wanna Know', 'Joe'],
#  ['359 ', 'I Remember', 'Keyshia Cole'],
#  ['360 ',
#   'Hold It Down (w\\/ Talib Kweli & Tyler Woods)',
#   '9th Wonder & Buckshot'],
#  ['361 ', 'Lord Watch Over Our Shoulders', 'Garnett Silk'],
#  ['362 ', "What's Luv (w\\/ Ashanti & Ja-Rule)", 'Fat Joe'],
#  ['363 ', 'Pretty Wings', 'Maxwell'],
#  ['364 ', 'Wine And Bend Over', 'Denise Belfon & Ghetto Flex'],
#  ['365 ', 'Bandelero', 'Pinchers'],
#  ['366 ', 'Benz & The Beama', 'Bounty Killer'],
#  ['367 ', 'Big Phat Fish (w\\/ Xtatik)', 'Machel Montano'],
#  ['368 ', 'What Happened To That Boy (w\\/ Clipse)', 'Baby'],
#  ['369 ', 'Dutty Badmind', 'Serani'],
#  ['370 ', 'Gully Side', 'Mavado'],
#  ['371 ', 'Cyaan Look Inna Wi Eye', 'Bugle'],
#  ['372 ', 'Anywhere We Go', 'Assassin'],
#  ['373 ', 'Move Ya Body', 'Nina Sky'],
#  ['374 ', 'Jook Gal', 'Elephant Man'],
#  ['375 ', 'Feel Alright', 'Sean Paul'],
#  ['376 ', 'Put In The Thing', 'Bunji Garlin'],
#  ['377 ', 'Raise Yuh Hand', 'Bunji Garlin'],
#  ['378 ', 'Skip To Ma Lue (w\\/ Ding Dong, Razz & Biggy)', 'Serani'],
#  ['379 ', 'Tell Me', 'Machel Montano'],
#  ['380 ', 'Diamond Girl', 'Ryan Leslie'],
#  ['381 ', 'Shoulda Let You Go (w\\/ Amina)', 'Keyshia Cole'],
#  ['382 ', 'Hate That I Love You (w\\/ Ne-Yo)', 'Rihanna'],
#  ['383 ', 'Light It Up (w\\/ Machel Montano)', 'Patrice Roberts'],
#  ['384 ', 'Take My Life', 'Micah Stampley'],
#  ['385 ', "We're Blessed", 'Fred Hammond & Radical For Christ'],
#  ['386 ', 'Touch My Body', 'Mariah Carey'],
#  ['387 ', 'Say Something (w\\/ Drake)', 'Timbaland'],
#  ['388 ', "Gangsta's Paradise (w\\/ LV)", 'Coolio'],
#  ['389 ', 'How You Do It Like That', 'Lisa Hype & Vybz Kartel'],
#  ['390 ', 'Hustling', 'Busy Signal'],
#  ['391 ', "I Can't Fight This Feeling", 'Shaggy'],
#  ['392 ', "Can't Let You Go", 'Coro'],
#  ['393 ', "Watcin' Meh (w\\/ Gailann)", 'Benjai'],
#  ['394 ', 'Turn Me On', 'Kevin Lyttle'],
#  ['395 ', 'Mamacita', 'Collie Buddz'],
#  ['396 ', 'Dance With You (w\\/ Mr. Vegas)', 'Machel Montano'],
#  ['397 ', 'Tight', 'Peter Ram'],
#  ['398 ', 'Hair Dresser Shop', 'Busy Signal'],
#  ['399 ', 'Boombastic (Remix)', 'Shaggy'],
#  ['400 ', 'Hot Like (w\\/ Serani)', 'Machel Montano'],
#  ['401 ', 'Homemade Wine', 'Scrunter'],
#  ['402 ', "When You're Mad", 'Ne-Yo'],
#  ['403 ', 'Stan', 'Eminem'],
#  ['404 ', "If I Didn't Know Better", 'Luther Vandross'],
#  ['405 ', "Beautiful (w\\/ Colby O'Donis & Kardinal Offishall)", 'Akon'],
#  ['406 ', "2012 (It Ain't The End)", 'Jay Sean'],
#  ['407 ', 'One Sweet Day (w\\/ Boyz II Men)', 'Mariah Carey'],
#  ['408 ', 'Up Out My Face', 'Mariah Carey'],
#  ['409 ', 'Crazy In Love', 'Beyonce'],
#  ['410 ', 'Bashment Party', 'Rayvon & Red Foxx'],
#  ['411 ', 'We Nuh Like', 'Spragga Benz'],
#  ['412 ', "Nuthin' But A G Thang (w\\/ Snoop Dogg)", 'Dr. Dre'],
#  ['413 ', 'If I Ruled The World (Imagine That) (w\\/ Lauryn Hill)', 'Nas'],
#  ['414 ', 'Holla Holla', 'Ja Rule'],
#  ['415 ', 'Lose My Mind (w\\/ Plies)', 'Young Jeezy'],
#  ['416 ', 'Angels (w\\/ The Notorious B.I.G.)', 'Diddy & Dirty Money'],
#  ['417 ', 'Row Like A Boat', 'Beenie Man'],
#  ['418 ', 'Galang Gal', 'T.O.K.'],
#  ['419 ', "Nuttin' Nuh Go So", 'Notch'],
#  ['420 ',
#   'Mo Money Mo Problems (w\\/ Mase & Puff Daddy)',
#   'The Notorious B.I.G.'],
#  ['421 ', 'Sycamore Tree', 'Lady Saw'],
#  ['422 ', 'Silent Violence', 'Beenie Man'],
#  ['423 ', 'Only Man', 'Buju Banton'],
#  ['424 ', 'Slam', 'Beenie Man'],
#  ['425 ', 'Punkie', 'Sean Paul'],
#  ['426 ', 'Romie', 'Beenie Man'],
#  ['427 ', 'Heights Of Great Men', 'Beenie Man'],
#  ['428 ', 'Man Is The Least', 'Lady Saw'],
#  ['429 ', "I've Got Your Man", 'Lady Saw'],
#  ['430 ', 'Ha Ha (Slow Down Son) (w\\/ Young Jeezy)', 'Fat Joe'],
#  ['431 ', 'Bad Girl (w\\/ Fabolous)', 'Black Buddafly'],
#  ['432 ', 'Sexy Love', 'Ne-Yo'],
#  ['433 ', "If You're Not The One", 'Daniel Bedingfield'],
#  ['434 ', 'You Complete Me', 'Keyshia Cole'],
#  ['435 ',
#   'Sex In Crazy Places (w\\/ Nicki Minaj, Trina & Bobby Valentino)',
#   'Gucci Mane'],
#  ['436 ', 'Stickwitu', 'The Pussycat Dolls'],
#  ['437 ', 'Take A Bow', 'Rihanna'],
#  ['438 ', 'Lay You Down', 'Usher'],
#  ['439 ', 'Confessions Part II', 'Usher'],
#  ['440 ', "I Just Can't Do This", 'K. Michelle'],
#  ['441 ', 'Be Prepared', 'Jamelody'],
#  ['442 ', 'Fiesta', 'R. Kelly'],
#  ['443 ', 'Jamboree (w\\/ Zhane)', 'Naughty By Nature'],
#  ['444 ', 'Back To The Crib (w\\/ Chris Brown)', 'Juelz Santana'],
#  ['445 ', 'Heavy T', 'Fay-Ann Lyons'],
#  ['446 ', 'Love All Over Me', 'Monica'],
#  ['447 ', 'Healing', 'Lady Saw & Beenie Man'],
#  ['448 ', 'Best I Ever Had', 'Drake'],
#  ['449 ', 'Gotta Man', 'Eve'],
#  ['450 ', "You're All I Need (w\\/ Mary J. Blige)", 'Method Man'],
#  ['451 ', "Put It On Me (w\\/ Vita & Lil' Mo)", 'Ja Rule'],
#  ['452 ', 'I Want To Know (w\\/ Monty G)', 'Positive'],
#  ['453 ', 'Temperature', 'Sean Paul'],
#  ['454 ', 'Run Out Pon Dem', 'Sizzla'],
#  ['455 ', 'Come Into My Room', 'Stacious & Mavado'],
#  ['456 ', 'Yuh Nuh Ready Fi Dis Yet', 'Tanya Stephens'],
#  ['457 ', 'Submarine Symphonika', 'The Submarines'],
#  ['458 ', 'Falsetto', 'The Dream'],
#  ['459 ', 'Last Bad John Of Kaiso', 'Kurt Allen'],
#  ['460 ', 'No Badjohn', 'Kurt Allen'],
#  ['461 ', 'Spongebob Squarepants Theme', 'Spongebob Squarepants'],
#  ['462 ', 'F.U.N. Song', 'Spongebob Squarepants'],
#  ['463 ', 'Night Shift', 'Busy Signal'],
#  ['464 ', 'One More Night', 'Busy Signal'],
#  ['465 ', 'Reach', 'Rizon'],
#  ['466 ', 'Roll It', 'Alison Hinds'],
#  ['467 ', 'Stalker', 'Kes The Band'],
#  ['468 ', 'Got Your Back (w\\/ Keri Hilson)', 'T.I.'],
#  ['469 ', 'Nina Bonita', 'Chino & Nacho'],
#  ['470 ', 'So Far, So Good (w\\/ Common)', 'Skillz'],
#  ['471 ', 'Sick (The Sequel)', 'Skillz'],
#  ['472 ', 'Yo Side Of The Bed', 'Trey Songz'],
#  ['473 ', 'Ready', 'Iwer George'],
#  ['474 ', 'My Girl', 'Kes The Band'],
#  ['475 ', 'Just A Dream', 'Nelly'],
#  ['476 ', 'One More Time (w\\/ Yardi Don)', 'Marc Mysterio'],
#  ['477 ', 'Gimme That', 'Ciara'],
#  ['478 ', "Let It Go (w\\/ Missy Elliott & Lil' Kim)", 'Keyshia Cole'],
#  ['479 ', 'Not In Ah Dat', 'Jadee'],
#  ['480 ',
#   'Love Him Like I Do (w\\/ Ruben Studdard & Mary Mary)',
#   'Deitrick Haddon'],
#  ['481 ', 'Never Let Go', 'Positive'],
#  ['482 ', 'Bad Medicine', 'Bon Jovi'],
#  ['483 ', 'You Are My Sunshine', 'Ray Charles'],
#  ['484 ', 'Speechless', 'Ciara'],
#  ['485 ', 'Alright', 'Pitbull'],
#  ['486 ', 'On The The Next One (feat. Swizz Beatz)', 'Jay-Z'],
#  ['487 ', 'If Love So Nice', 'Junior Kelly'],
#  ['488 ', "It's A Pity", 'Tanya Stephens'],
#  ['489 ', 'These Streets', 'Tanya Stephens'],
#  ['490 ', 'Bag A Talking', 'Deva Bratt'],
#  ['491 ', 'Smile (w\\/ Ataklan)', 'Terri Lyons'],
#  ['492 ', 'Te Amo', 'Rihanna'],
#  ['493 ', 'Tic Toc', 'Busy Signal'],
#  ['494 ', 'Cool Baby', 'Busy Signal'],
#  ['495 ', "That's My Attitude", 'Trina'],
#  ['496 ', 'Armada Latina (w\\/ Marc Anthony & Pitbull)', 'Cypress Hill'],
#  ['497 ', 'Worn Me Down', 'Rachael Yamagata'],
#  ['498 ', 'Radiance', 'Keith Jarrett'],
#  ['499 ', 'ABC', 'The Jackson 5'],
#  ['500 ', "Don't Stop 'Til You Get Enough", 'Michael Jackson'],
#  ['501 ', 'Thriller', 'Michael Jackson'],
#  ['502 ', 'Dirty Diana', 'Michael Jackson'],
#  ['503 ', 'Speed Demon', 'Michael Jackson'],
#  ['504 ', 'Leave Me Alone', 'Michael Jackson'],
#  ['505 ', 'Are You The One?', 'The Presets'],
#  ['506 ', 'Money Eh No Problem', 'Shorty'],
#  ['507 ', 'Dirty Little Thing', 'Velvet Revolver'],
#  ['508 ', 'Gal Yuh A Lead', 'T.O.K.'],
#  ['509 ', 'Money 2 Burn', 'T.O.K.'],
#  ['510 ', 'Hey Ladies', 'T.O.K.'],
#  ['511 ', 'Shake Yuh Bam Bam', 'T.O.K.'],
#  ['512 ', 'Couple Up', 'T.O.K.'],
#  ['513 ', 'Footprints (When You Cry)', 'T.O.K.'],
#  ['514 ', 'How Sweet It Is To Be Loved By You', 'Marvin Gaye'],
#  ['515 ', "You're A Wonderful One (w\\/ The Supremes)", 'Marvin Gaye'],
#  ['516 ', "When I'm Gone", 'Brenda Holloway'],
#  ['517 ', 'Give It 2 Me', 'Madonna'],
#  ['518 ', 'So What', 'Pink'],
#  ['519 ', 'Someday', 'Capleton'],
#  ['520 ', 'Tables Will Turn (w\\/ Baby Cham)', 'Foxy Brown'],
#  ['521 ', 'I Fell In Love With The DJ (w\\/ Cham)', "Che'Nelle"],
#  ['522 ', 'Got To Be Real', 'Cheryl Lynn'],
#  ['523 ', 'Ride Or Die', "Ce'Cile"],
#  ['524 ', 'Doh tie Meh Down', 'Ronnie McIntosh'],
#  ['525 ', 'Rude Boy', 'Rihanna'],
#  ['526 ', "Can't Let My Love Go (w\\/ Shaggy)", 'Alison Hinds'],
#  ['527 ', 'California', 'Phantom Planet'],
#  ['528 ', 'Headsprung (w\\/ Timbaland)', 'LL Cool J'],
#  ['529 ', 'Like I Love You (w\\/ The Clipse)', 'Justin Timberlake'],
#  ['530 ', 'The More I See You', 'Eliane Elias'],
#  ['531 ', 'Late Night Call', 'Eric Bolvin'],
#  ['532 ', 'Dance Because You Can', 'Nestor Torres'],
#  ['533 ', 'Blue Runway', 'Mike Stern'],
#  ['534 ', 'Big City', 'Joe Sherbanee'],
#  ['535 ', 'Honesty', 'Jeff Kashiwa'],
#  ['536 ', 'Here And Now', 'Luther Vandross'],
#  ['537 ', 'Lowdown (Unplugged)', 'Boz Scaggs'],
#  ['538 ', 'For The Love Of You', 'Hil St. Soul'],
#  ['539 ', 'You Are Everything (Radio Edit One)', 'Kirk Whalum'],
#  ['540 ', "Baby That's Backatcha", 'Walter Beasley'],
#  ['541 ', 'Here To Stay', 'Marion Meadows'],
#  ['542 ', 'Possibilities', 'Amp Fiddler'],
#  ['543 ', 'The Way Look Tonight', 'Rod Stewart'],
#  ['544 ', 'Soulful Strut', 'Grover Washington, Jr.'],
#  ['545 ', 'Ritmo Y Romance', 'Kenny G'],
#  ['546 ', "I Can't Go For That", 'Marcus Johnson'],
#  ['547 ', 'Honey-Dipped', 'Dave Koz'],
#  ['548 ', "Can't Let You Go (The Sha La Song)", 'Dave Koz'],
#  ['549 ', 'Sand On My Feet', 'Donna Summer'],
#  ['550 ', 'Easy Love (w\\/ Stanley Jordan)', 'Novecento'],
#  ['551 ', 'Near The Cross', 'The Myra Walker Singers'],
#  ['552 ', 'So Good To Be Here', 'The Barnes Family'],
#  ['553 ', 'Vapor', 'Soulive'],
#  ['554 ', 'Only The Strong Survive', 'Jerry Butler'],
#  ['555 ', 'Mathematics Of Love (w\\/ Kim Burrell)', 'George Clinton'],
#  ['556 ', 'Atomic Dog', 'George Clinton'],
#  ['557 ', '(Not Just) Knee Deep', 'Funkadelic'],
#  ['558 ', 'Give Up The Funk (Tear The Roof Off The Sucker)', 'Parliament'],
#  ['559 ', 'Flash Light', 'Parliament'],
#  ['560 ', 'If I Were A Boy', 'Beyonce'],
#  ['561 ', 'The Lady In My Life', 'Maysa'],
#  ['562 ',
#   'Miss Independent (She Got Her Own) (w\\/ Fabolous & Jamie Foxx)',
#   'Ne-Yo'],
#  ['563 ', "I'm In Love", 'Ginuwine'],
#  ['564 ', 'In Love With Another Man', 'Jazmine Sullivan'],
#  ['565 ', 'Something Every Day', 'Swing Out Sister'],
#  ['566 ', 'Celebrate', 'Smokie Norful'],
#  ['567 ', 'Got Me Going', 'Day26'],
#  ['568 ', 'Homeless', 'Charlie Wilson'],
#  ['569 ', 'I Apologize', 'K-Ci'],
#  ['570 ', 'Giving Myself', 'Jennifer Hudson'],
#  ['571 ', 'Wonderful', 'Marques Houston'],
#  ['572 ', 'My R&B (w\\/ Barbi Esco)', 'Randy Jackson'],
#  ['573 ', 'Oh', 'Kevon Edmonds'],
#  ['574 ', 'Lucky', 'Ken Navarro'],
#  ['575 ', 'Ahead Of The Weather', 'Oli Silk'],
#  ['576 ', 'One Chance', 'Paul Hardcastle'],
#  ['577 ', 'Living For the City', 'Johnny James'],
#  ['578 ', 'L.A. Citylights', 'Candy Dulfer'],
#  ['579 ', 'Meltdown', 'Lisa Hilton'],
#  ['580 ', 'Come As You Are', 'Mindi Abair'],
#  ['581 ', 'Rocket Love', 'Eric Bolvin'],
#  ['582 ', 'Broken Silence', 'Shilts'],
#  ['583 ', 'To Love Her', 'Marion Meadows'],
#  ['584 ', 'Oh Yeah', 'Walter Beasley'],
#  ['585 ', "Lookin' For A Change", 'Joe McBride'],
#  ['586 ', 'Stone Flower', 'Antonio Carlos Jobim'],
#  ['587 ', "Ain't No Sunshine", 'Emily King'],
#  ['588 ', 'Get Ready', 'Antoinette Montague'],
#  ['589 ', 'Night On The Town', 'Eric Darius'],
#  ['590 ', 'Learning To Fly', 'Andy Scott'],
#  ['591 ', 'Angela (Theme From Taxi)', 'Bob James'],
#  ['592 ', 'Running', 'Eliane Elias'],
#  ['593 ', 'We Got Love', 'Ryan Shaw'],
#  ['594 ', 'Rock Steady', 'Richard Elliot'],
#  ['595 ', 'Love Theory (w\\/ Will Downing)', 'Maysa'],
#  ['596 ', 'Cubanova', 'Marc Antoine'],
#  ['597 ', 'Grass Roots', 'Joyce Cooling'],
#  ['598 ', 'And Then I Knew', 'Dave Koz'],
#  ['599 ', 'Get Your Way', 'Jamie Cullum'],
#  ['600 ', 'I Wish', 'Mark Whitfield'],
#  ['601 ', 'Ride Wit U', 'Nyr'],
#  ['602 ', 'Swing Piece', 'Manu Katche'],
#  ['603 ', 'Ode To Billy Joe', 'Bradley Leighton'],
#  ['604 ', 'Baila', 'Novello'],
#  ['605 ', 'Ritmo De Otono (w\\/ Dave Koz)', 'Bernie Williams'],
#  ['606 ', 'Feel What You Want', 'Kristine W'],
#  ['607 ', "I Ain't Superstitious", "Howlin' Wolf"],
#  ['608 ', 'Superstition', 'Stevie Wonder'],
#  ['609 ', 'Chirpy Chirpy Cheep Cheep', 'Mac & Katie Kissoon'],
#  ['610 ', 'Knock On Wood', 'Eddie Floyd'],
#  ['611 ', 'Eighteen With A Bullet', 'Pete Wingfield'],
#  ['612 ', 'Spooky (w\\/ Dennis Yost)', 'Classics IV'],
#  ['613 ', 'What A Man', 'Linda Lyndell'],
#  ['614 ', 'Haunted House Of Rock', 'Whodini'],
#  ['615 ', "Don't Leave Me This Way", 'Thelma Houston'],
#  ['616 ', 'A Nightmare On My Street', 'DJ Jazzy Jeff & The Fresh Prince'],
#  ['617 ', 'Boogie Nights', 'Heatwave'],
#  ['618 ', 'Funkytown', 'Lipps, Inc.'],
#  ['619 ', 'Serpentine Fire', 'Earth, Wind & Fire'],
#  ['620 ', 'In The Midnight Hour', 'Wilson Pickett'],
#  ['621 ', 'The Love You Save', 'The Jackson 5'],
#  ['622 ', 'I Love How You Love Me', 'The Paris Sisters'],
#  ['623 ', 'Shop Around', 'The Miracles'],
#  ['624 ', 'Band Of Gold', 'Freda Payne'],
#  ['625 ', "Little Bit O' Soul", 'The Music Explosion'],
#  ['626 ', 'Soldier Boy', 'The Shirelles'],
#  ['627 ', 'Heat Wave', 'Martha & The Vandellas'],
#  ['628 ', 'Le Freak', 'Chic'],
#  ['629 ', 'Everyday People', 'Sly & The Family Stone'],
#  ['630 ', "She's Gone", 'Daryl Hall & John Oates'],
#  ['631 ', 'Do You Wanna Get Funky With Me', 'Peter Brown'],
#  ['632 ', "If I Can't Have You", 'Yvonne Elliman'],
#  ['633 ', 'Oh Sheila', 'Ready For The World'],
#  ['634 ', 'God Favored Me (Part I)', 'Hezekiah Walker'],
#  ['635 ', "He Won't Change (w\\/ Darrell Luster)", 'Rev. F.C. Barnes'],
#  ['636 ', 'Heaven On My Mind', 'Luther Barnes & The Sunset Jubilaires'],
#  ['637 ', 'Time Out!!!', 'Castro Coleman & Highly Favored'],
#  ['638 ', 'Work A Miracle', "Spencer Taylor & The Highway QC's"],
#  ['639 ', 'He Has His Hands On You', 'Marvin Sapp'],
#  ['640 ', 'Say Thank You', 'Lisa Page Brooks'],
#  ['641 ', "It's Your Time", 'Luther Barnes & The Sunset Jubilaires'],
#  ['642 ', "He's Preparing Me", 'Daryl Coley'],
#  ['643 ', "He's An On Time God", 'Dottie Peoples'],
#  ['644 ', 'Strong Man', 'Shirley Caesar'],
#  ['645 ', 'Order My Steps', 'The GMWA Women Of Worship'],
#  ['646 ', 'Resting Easy', 'Refuge'],
#  ['647 ', "Helen's Testimony", 'Helen Baylor'],
#  ['648 ', 'Holy Is The Lamb', 'Oleta Adams'],
#  ['649 ', 'Live For You', 'John P. Kee & The New Life Community Choir'],
#  ['650 ', 'We Acknowledge You', 'Karen Clark-Sheard'],
#  ['651 ', 'Greatest Part Of Me', 'Virtue'],
#  ['652 ', 'Peace And Favor Rest On Us', 'Kurt Carr & The Kurt Carr Singers'],
#  ['653 ', 'So Many Times', 'Dorinda Clark-Cole'],
#  ['654 ', 'Born Again', 'Lejuene Thompson'],
#  ['655 ', 'Double Down', 'Joe McBride'],
#  ['656 ', 'On The Strip', 'Marc Antoine'],
#  ['657 ', 'Where Are You Now?', 'Lisa Hilton'],
#  ['658 ', 'We Got The Groove', 'Gerald Albright'],
#  ['659 ', "Hold What You've Got", 'Joe Tex'],
#  ['660 ', 'La La (Means I Love You)', 'The Delfonics'],
#  ['661 ', 'KT', 'Mike Stern'],
#  ['662 ', 'Lovely Day', 'The Philippe Saisse Trio'],
#  ['663 ', 'Let The Top Down', 'Marion Meadows'],
#  ['664 ', 'Cast Your Fate To The Wind', 'Vince Guaraldi'],
#  ['665 ', 'Out Of The Blue', 'Mindi Abair'],
#  ['666 ', 'Go', 'Brian Culbertson'],
#  ['667 ', "Can't Stop The Feeling", 'Kyle Wolverton'],
#  ['668 ', 'Tropical', 'Chuck Loeb'],
#  ['669 ', 'Slow Ride Home', 'Acoustic Alchemy'],
#  ['670 ', 'Always Thinking Of You', 'Nick Colionne'],
#  ['671 ', 'Wake Up Call', 'Bradley Leighton'],
#  ['672 ', 'Never Far Away', 'Rush Of Fools'],
#  ['673 ', "It's Growing", 'James Taylor'],
#  ['674 ', "You Don't Know", 'Cabo Frio'],
#  ['675 ', 'Inside Out', 'Cal Harris Jr.'],
#  ['676 ', 'Dirty Martini (w\\/ Will Donato)', 'Johnny Meza'],
#  ['677 ', 'Simply Beautiful', 'Al Green'],
#  ['678 ', 'Ilusion Pasajera', 'Los Bukis'],
#  ['679 ', 'Que De Raro Tiene', 'Vicente Fernandez'],
#  ['680 ', 'La Gallina', 'Fito Olivares'],
#  ['681 ', 'No Te Olvidare', 'Mazz'],
#  ['682 ', 'Quiero Amanecer Con Alguien', 'Daniela Romo'],
#  ['683 ', 'No Tengo Dinero', 'Juan Gabriel'],
#  ['684 ', 'Gema', "Los Dandy's"],
#  ['685 ', 'Stronger', 'The Canton Spirituals'],
#  ['686 ', 'Hallelujah Anyhow (w\\/ The AARC Mass Choir)', 'Rev. Clay Evans'],
#  ['687 ', "I'm Still Here", 'Mississippi Mass Choir'],
#  ['688 ', "Trouble Don't Last Always", 'Rev. Timothy Wright'],
#  ['689 ', 'Living Testimony', 'Doug Williams'],
#  ['690 ',
#   'Lily In The Valley (w\\/ John P. Kee)',
#   'V.I.P. Music & Arts Seminar Mass Choir'],
#  ['691 ', 'I Know The Lord Will', 'Bishop G.E. Patterson'],
#  ['692 ', 'Midtown 9 AM', 'Dave Frank'],
#  ['693 ', 'Down Time', 'Corey Christiansen'],
#  ['694 ', "Is You Is Or Is You Ain't My Baby", 'Melissa Morgan'],
#  ['695 ', 'Facinating Rhythm', 'Frank Vignola'],
#  ['696 ', 'Song For My Father', 'Victor Wooten'],
#  ['697 ', 'Take Love Easy', 'Sophie Milman'],
#  ['698 ', 'Botswana Bossa Nova', 'David Benoit'],
#  ['699 ', "Love's Gonna Bite You Back", 'Ray Charles'],
#  ['700 ', 'It Hurts To Be In Love', 'Ray Charles'],
#  ['701 ', "I'm Gonna Keep On Singin'", 'Ray Charles'],
#  ['702 ', 'Land Of...', 'St. Germain'],
#  ['703 ', 'My One And Only Love (w\\/ Roy Hargrove)', 'Rod Stewart'],
#  ['704 ', 'Pick Somebody Up', 'Raul Midon'],
#  ['705 ', 'Elevation', 'Jackiem Joyner'],
#  ['706 ', 'Beat Street', 'David Benoit'],
#  ['707 ', 'The In Crowd', 'Ramsey Lewis'],
#  ['708 ', 'A Whiter Shade Of Pale', 'Matt Belsante'],
#  ['709 ', 'Just My Style', 'Marion Meadows'],
#  ['710 ', 'Forever (w\\/ Musiq Soulchild)', 'The Floacist'],
#  ['711 ', 'Pandemonium', 'Lisa Hilton'],
#  ['712 ', 'Wherever You Are', 'Brian Hughes'],
#  ['713 ', 'Cascavel', 'Antonio Adolfo & Carol Saboya'],
#  ['714 ', 'Once In A Blue Moon', 'Van Morrison'],
#  ['715 ', 'Pretty Wife', 'Reggie Foster'],
#  ['716 ', "Something 'Bout You", 'Kristin Scott Benson'],
#  ['717 ', 'Build A House', 'John P. Kee & The New Life Community Choir'],
#  ['718 ', 'I Came To Jesus', 'New Direction'],
#  ['719 ', 'Right On Time (Live)', "Lee Williams & The Spiritual QC's"],
#  ['720 ', "And Yet I'm Still Saved", 'The Tri-City Singers'],
#  ['721 ', 'These Thorns', 'Angela Spivey And The Voices Of Victory'],
#  ['722 ',
#   'Jesus Is My Help',
#   'Hezekiah Walker & The Love Fellowship Crusade Choir'],
#  ['723 ', 'Worthy', 'Virtue'],
#  ['724 ', 'God Great God', 'Kurt Carr & The Kurt Carr Singers'],
#  ['725 ', 'I Made It', "Keith 'Wonderboy' Johnson & The Spiritual Voices"],
#  ['726 ', 'Lord Prepare Me', 'The West Angeles COGIC Mass Choir'],
#  ['727 ', "It's Alright (Send Me)", 'Winans Phase 2'],
#  ['728 ', 'No Way (The G.A. Chant)', 'Tye Tribbett & G.A.'],
#  ['729 ', 'I Speak Life (w\\/ Donnie McClurkin)', 'Donald Lawrence'],
#  ['730 ', 'Renewed', 'Sheri Jones-Moffett'],
#  ['731 ',
#   "I've Got A Testimony (w\\/ The AARC Mass Choir)",
#   'Rev. Clay Evans'],
#  ['732 ', 'We Praise You', 'The McClurkin Project'],
#  ['733 ', 'No Battle, No Blessing', 'Shari Addison'],
#  ['734 ', 'Still Say, Thank You', 'Smokie Norful'],
#  ['735 ', 'Hang On', 'The Soul Seekers'],
#  ['736 ', 'Joy', 'Niyoki'],
#  ['737 ', 'Let Us Worship Him', 'Yolanda Adams'],
#  ['738 ', 'Te Casaste', 'Ladron'],
#  ['739 ', 'El Dicharachero', 'Antonio Aguilar'],
#  ['740 ', 'En El Ultimo Trago', 'Jose Alfredo Jimenez'],
#  ['741 ', 'Los Mandados', 'Vicente Fernandez'],
#  ['742 ', 'Mi Ranchito', 'Vicente Fernandez'],
#  ['743 ', 'Derecho De Antiguedad', 'La Original Banda El Limon'],
#  ['744 ', 'Volver, Volver', 'Vicente Fernandez'],
#  ['745 ', 'Adorable Mentirosa (w\\/ Banda El Recodo)', 'Juan Gabriel'],
#  ['746 ', 'Bon Bon', 'Pitbull'],
#  ['747 ', 'Hoy En Tu Dia', 'Conjunto Primavera'],
#  ['748 ', 'Soy Enamorado', 'Titanes De Durango'],
#  ['749 ',
#   'La Peinada (La Peinadita)',
#   'Chuy Lizarraga Y Su Banda Tierra Sinaloense'],
#  ['750 ', 'La Escuelita', 'Banda Los Recoditos'],
#  ['751 ', 'El Zacatecano', 'Pepe Aguilar'],
#  ['752 ', 'Arremangala Arrempujala', 'Banda Machos'],
#  ['753 ', 'Me Gusta Todo De Ti', 'Banda El Recodo De Don Cruz Lizarraga'],
#  ['754 ', 'Adoro (w\\/ Lupe Esparza)', 'K-Paz De La Sierra'],
#  ['755 ', 'Te Amo', 'Cumbre Nortena'],
#  ['756 ', 'Mensajitos Por Telefono', 'El Grupo Libra'],
#  ['757 ', 'Sangre Caliente', 'Los Tigres Del Norte'],
#  ['758 ', 'Te Conquistare', 'Los Titanes De Durango'],
#  ['759 ', 'Par De Anillos', 'Viento Y Sol'],
#  ['760 ', 'Espero', 'Grupo Montez De Durango'],
#  ['761 ', 'La Faldita', 'Patrulla 81'],
#  ['762 ', 'El Sonidito (El Ruidito)', 'Hechizeros Band'],
#  ['763 ', 'Amor Te Amo', 'Tierra Cali'],
#  ['764 ', 'Asi Te Quiero', 'La Arrolladora Banda El Limon'],
#  ['765 ', 'Cielo Nublado', 'Pesado'],
#  ['766 ', 'La Huella De Mis Besos', 'Los Tiranos Del Norte'],
#  ['767 ', 'Te Vas, Te Vas', 'Sonora Siguaray'],
#  ['768 ', 'Ensename A Olvidarte', 'Intocable'],
#  ['769 ',
#   'Tienes Lo Que Me Gusta',
#   'Los Creadorez Del Pasito Duranguense De Alfredo Ramirez'],
#  ['770 ', 'Si Te Perdiera', 'Industria Del Amor'],
#  ['771 ', 'Si Me Recuerdas', 'Los Bukis'],
#  ['772 ', 'Hasta Mi Final', 'El Trono De Mexico'],
#  ['773 ', 'Debajo De Los Laureles', "Los Player's"],
#  ['774 ', 'Al Menos', 'La Original Banda Limon'],
#  ['775 ', 'Y Tu Que Harias?', 'Fidel Rueda'],
#  ['776 ', 'Lo Que No Se Vale', 'Liberacion'],
#  ['777 ', 'Tu Adios No Mata', 'Intocable'],
#  ['778 ', 'Cantarito Nuevo', 'Martin Ayala Y Su Grupo Tierra Yaqui'],
#  ['779 ', 'Tristes Recuerdos', 'Ramon Ayala Y Sus Bravos Del Norte'],
#  ['780 ', 'Cumbia Francesa', 'Isabela'],
#  ['781 ', 'Una Noche En Tu Vida', 'Ezequiel Pena'],
#  ['782 ', 'Te Amo', 'Los Horoscopos De Durango'],
#  ['783 ', 'Hipnotika', 'A.B. Quintanilla'],
#  ['784 ', 'Low Rider', 'War'],
#  ['785 ', 'Los Reproches Del Viento', 'Patrulla 81'],
#  ['786 ', 'Los Ahogados Del Rio Grande', 'Los Morros Del Norte'],
#  ['787 ', 'Te Voy A Olvidar', 'Pancho Barraza'],
#  ['788 ', 'Te Ves Fatal', 'El Trono De Mexico'],
#  ['789 ', 'Quiereme Mas', 'Patrulla 81'],
#  ['790 ', 'Ni Rosas Ni Juguetes', 'Paulina Rubio'],
#  ['791 ', 'Dime', 'Liberacion'],
#  ['792 ', 'Mi Primera Vez', 'Conjunto Primavera'],
#  ['793 ', 'No Es Tan Solo La Mitad', 'La Adictiva Banda San Jose De Mesillas'],
#  ['794 ', 'Y Aunque Te Duela', 'Fidel Rueda'],
#  ['795 ', 'Loco Por Ti', 'Los Temerarios'],
#  ['796 ', 'Ya No Supe Amar', 'Graciela Beltran'],
#  ['797 ', 'Mil Horas', 'Mariana'],
#  ['798 ', 'Pobre De Mi Corazon', 'Conjunto Primavera'],
#  ['799 ', 'Dime', 'Grupo Bryndis'],
#  ['800 ', 'Aunque Tengas La Razon', 'Cuisillos'],
#  ['801 ', 'Rica Y Apretadita (w\\/ Melissa Jimenez)', 'Kumbia All Starz'],
#  ['802 ',
#   'Por Quien Me Dejas',
#   'Los Creadorez Del Pasito Duranguense De Alfredo Ramirez'],
#  ['803 ', 'Te Quiero Tanto', 'Diana Reyes & El Trono De Mexico'],
#  ['804 ', 'No Soy Nada', 'Lider Musical'],
#  ['805 ', 'Ni Con Otro Corazon', 'Pedro Fernandez'],
#  ['806 ', 'Niegalo', 'Los Horoscopos De Durango'],
#  ['807 ', 'Quien Entiende A Las Mujeres', 'La Maquinaria Nortena'],
#  ['808 ', 'Viejo Lobo De Mar', 'Lalo Mora'],
#  ['809 ', 'Tu Ultima Parranda', 'Paquita La Del Barrio'],
#  ['810 ', 'Indita Mia', 'Banda Brava'],
#  ['811 ', 'Un Dia De Estos', 'Duelo'],
#  ['812 ', 'El Cuarto De La Muerte', 'Cristaleros Del Sur'],
#  ['813 ', 'Como Un Tatuaje', 'K-Paz De La Sierra'],
#  ['814 ', 'Los Chones', 'El Chico Elizalde'],
#  ['815 ', 'Que Nadie Sepa', 'Liberacion'],
#  ['816 ', 'No Llores Mas', 'Zaino'],
#  ['817 ', 'Como Te Quiero', 'Cheno Chaidez'],
#  ['818 ', 'No Pude Quitarte Las Espinas', 'Conjunto Atardecer'],
#  ['819 ', 'Calla (w\\/ Ben De Leon)', 'Jimmy Gonzalez Y Grupo Mazz'],
#  ['820 ', 'Que Se Mueran Los Feos', "Sergio Vega 'El Shaka'"],
#  ['821 ',
#   'Si Supieras (w\\/ Aleks Syntek)',
#   'Margarita La Diosa De La Cumbia'],
#  ['822 ', 'Dime Una Y Otra Vez', 'El Chapo De Sinaloa'],
#  ['823 ', 'Culpable O Inocente', 'Jenni Rivera'],
#  ['824 ',
#   'Yo Nunca, Tu Siempre (w\\/ Rocio Sandoval)',
#   'Dareyes De La Sierra'],
#  ['825 ', 'Una Obsesion', 'La Calma'],
#  ['826 ', 'La Muy Muy', 'Amandititita'],
#  ['827 ', 'Can U Werk Wit Dat', 'The Fixxers'],
#  ['828 ', 'Winner (w\\/ Justin Timberlake)', 'Jamie Foxx'],
#  ['829 ', 'Ice Cream Paint Job', 'Dorrough Music'],
#  ['830 ', 'Make Up Bag', 'The Dream'],
#  ['831 ', 'The Next Episode (w\\/ Snoop Dogg & Nate Dogg)', 'Dr. Dre'],
#  ['832 ', 'Sunshine (w\\/ Lea)', "Lil' Flip"],
#  ['833 ', 'How Do U Want It (w\\/ K-Ci & JoJo)', '2Pac'],
#  ['834 ', 'All Night Long', 'Mary Jane Girls'],
#  ['835 ', 'Fire Water', 'Hitman'],
#  ['836 ', 'Baila Mi Corazon', 'Belanova'],
#  ['837 ', "Outside The Trains Don't Run On Time", 'Gang Of Four'],
#  ['838 ', 'Imma Be', 'Black Eyed Peas'],
#  ['839 ', 'Ice Box', 'Omarion'],
#  ['840 ', 'Outta Control (w\\/ Pitbull)', 'Baby Bash'],
#  ['841 ', 'Im In The House (w\\/ Zuper Blahq)', 'Steve Aoki'],
#  ['842 ', 'California Love (w\\/ Dr. Dre & Roger Troutman)', '2Pac'],
#  ['843 ', 'I Get Around', '2Pac'],
#  ['844 ', 'Me Against The World', '2Pac'],
#  ['845 ', 'So Many Tears', '2Pac'],
#  ['846 ', 'What A Wonderful World', 'Jon Secada'],
#  ['847 ', 'Back To Juan', 'Candy Dulfer'],
#  ['848 ', 'Monday Speaks (w\\/ Norman Brown)', 'Everette Harp'],
#  ['849 ', 'Shag (w\\/ Chad Smith)', 'Bombastic Meatbats'],
#  ['850 ', 'Till You Come To Me', 'Spencer Day'],
#  ['851 ', 'Tokyo', 'Oli Silk'],
#  ['852 ', 'Love Is Sacrifice', 'Bruce Sudano'],
#  ['853 ', 'Lovely Day', 'Walter Beasley'],
#  ['854 ', 'Down To It', 'Jack Prybylski'],
#  ['855 ', 'And I Love Her', 'Kenny Lattimore'],
#  ['856 ', "Walkin' My Baby Back Home", 'Natalie Cole & Nat King Cole'],
#  ['857 ', 'Built For It', 'Joe Taylor'],
#  ['858 ', "Will It Go 'Round In Circles", 'Blake Aaron'],
#  ['859 ', 'Sunday Morning', 'Euge Groove'],
#  ['860 ', 'Good To Go', 'Steve Oliver'],
#  ['861 ', 'Better Days', 'Steve Baxter'],
#  ['862 ', 'Love You Found Me', 'Paul Brown'],
#  ['863 ', 'Fall Again', 'Kenny G'],
#  ['864 ', 'Beyond Forever', 'Bruce Sudano'],
#  ['865 ', "I'm Not Alone (Who Loves You?)", 'Eliane Elias'],
#  ['866 ', 'Candie', 'Lin Rountree'],
#  ['867 ', "Ellie's Theme", 'Walter Beasley'],
#  ['868 ', 'One Thing For Certain', 'J. Sylvester'],
#  ['869 ', 'Mystery', 'Lisa Hilton'],
#  ['870 ', 'Lay It Back', 'Paul Jackson, Jr.'],
#  ['871 ', 'I Put A Spell On You', 'Queen Latifah'],
#  ['872 ', 'How Does It Feel', 'Anita Baker'],
#  ['873 ', 'D Fuse The Situation', 'Pieces Of A Dream'],
#  ['874 ', 'Night Crawler', 'Bob James'],
#  ['875 ', 'Song Of Passion', 'Kim Waters'],
#  ['876 ', 'Deep Chill', 'Bona Fide'],
#  ['877 ', "Sinner's Prayer", 'Deitrick Haddon'],
#  ['878 ', 'Stay Saved', 'Canton Jones'],
#  ['879 ', "Maybe God Is Tryin' To Tell You Somethin'", 'Quincy Jones'],
#  ['880 ', 'I Love The Lord', 'Phillip Carter & SOV'],
#  ['881 ', 'Station To Station', 'David Bowie'],
#  ['882 ', 'I Got You', 'Leona Lewis'],
#  ['883 ', 'Best Best', 'Missy Elliott'],
#  ['884 ', "You're The Only One", 'Eric Benet'],
#  ['885 ', "Tumblin' Down", 'Jenna Andrews'],
#  ['886 ', 'Heartless', 'Kanye West'],
#  ['887 ', 'Stronger', 'Mary J. Blige'],
#  ['888 ', 'I Gotta Feeling', 'Black Eyed Peas'],
#  ['889 ', 'Written On Her (w\\/ Jay Sean)', 'Birdman'],
#  ['890 ', 'Knock You Down (w\\/ Ne-Yo & Kanye West)', 'Keri Hilson'],
#  ['891 ', 'Face Drop', 'Sean Kingston'],
#  ['892 ', 'Impossible', 'Shontelle'],
#  ['893 ', 'Whatever You Like', 'T.I.'],
#  ['894 ', 'Put On (w\\/ Kanye West)', 'Young Jeezy'],
#  ['895 ', 'Battlefield', 'Jordin Sparks'],
#  ['896 ', 'Shut It Down (feat Akon)', 'Pitbull'],
#  ['897 ', 'Stand!', 'Sly & The Family Stone'],
#  ['898 ', 'Wade In The Water', 'Lois Deloatch'],
#  ['899 ', 'Good Morning Heartache', 'Lois Deloatch'],
#  ['900 ', 'Pennies From Heaven', 'Lois Deloatch'],
#  ['901 ', 'The Look Of Love (w\\/ Fergie)', 'Sergio Mendes'],
#  ['902 ', 'All In Good Time', 'Larry Carlton'],
#  ['903 ', 'Hallelujah I Love Her So (w\\/ James Taylor)', 'David Sanborn'],
#  ['904 ', 'B.B.B.', 'Sons Brothers & Wrestlers'],
#  ['905 ', 'My Heart Will Go On', 'Kenny G'],
#  ['906 ', 'Every Time We Say Goodbye', 'Rod Stewart'],
#  ['907 ', 'The Way She Walks', 'Boney James'],
#  ['908 ', 'Yours', 'Sara Gazarek'],
#  ['909 ', 'Out Of My Head', 'Lionel Richie'],
#  ['910 ', 'Winds Of Change', 'Airborne'],
#  ['911 ', 'Bogota By Bus', 'Jesse Cook'],
#  ['912 ', 'Street Life', 'U-Nam'],
#  ['913 ', 'Blossom', 'Everette Harp'],
#  ['914 ', 'Moonlight Samba', 'Lawson Rollins'],
#  ['915 ', 'The Rhythm Method', 'Paul Brown'],
#  ['916 ', 'Rouler Sa Bosse', 'Bruce Cockburn'],
#  ['917 ', 'Word Up', 'Joe McBride'],
#  ['918 ', 'Lights Out San Francisco', 'Craig Chaquico'],
#  ['919 ', 'Sara Smile', 'Boyz II Men'],
#  ['920 ', "California Dreamin'", 'Queen Latifah'],
#  ['921 ', 'On The Rocks', 'Matt Marshak'],
#  ['922 ', 'City Lights', 'Nelson Rangell'],
#  ['923 ', 'I Am A Song', 'Sara Wasserman'],
#  ['924 ', "West Coast Coolin'", 'Norman Brown'],
#  ['925 ', 'Move On Up', 'Richard Elliot'],
#  ['926 ', 'Afterglow', 'Pamela Williams'],
#  ['927 ', "I Can't Stop", 'Al Green'],
#  ['928 ', 'Just For Fun', 'Lisa Hilton'],
#  ['929 ', 'Before You Leave', 'Everette Harp'],
#  ['930 ', 'One Mint Julep', 'Poncho Sanchez'],
#  ['931 ', 'El Alba', 'Camiel'],
#  ['932 ', 'Deep In Love', 'Kim Waters'],
#  ['933 ', 'Time Is Tight', "Booker T. & The MG's"],
#  ['934 ', "He's A Rebel", 'The Crystals'],
#  ['935 ', 'Disco Duck (Part 1)', 'Rick Dees & His Cast Of Idiots'],
#  ['936 ', 'MK Ultra', 'Muse'],
#  ['937 ', 'Jamie, My Intentions Are Bass', '!!!'],
#  ['938 ', 'Hypnotize U', 'N.E.R.D.'],
#  ['939 ', 'Yamaha', 'The Dream'],
#  ['940 ', 'Free', 'Bilal'],
#  ['941 ', 'Mirrorage', 'Glasser'],
#  ['942 ', 'Terrible Love', 'The National'],
#  ['943 ', 'No Worlds\\/No Thoughts', 'Swans'],
#  ['944 ', 'Lucky', 'Avey Tare'],
#  ['945 ', 'Somebody To Love Me', 'Mark Ronson & The Business Intl'],
#  ['946 ', 'The BBQ (w\\/ Rah Digga & Rage)', 'Eternia & Moss'],
#  ['947 ', 'National Anthem (F_ck The World)', 'Freddie Gibbs'],
#  ['948 ', 'Speaking In Tongues', "Cam'ron & Vado"],
#  ['949 ', "Tito's Way", 'The Juan Maclean'],
#  ['950 ', 'Time Of The Assassins', 'Charlotte Gainsbourg'],
#  ['951 ', "It's Only Paper", 'Ozomatli'],
#  ['952 ', 'Oh My', 'Gin Wigmore'],
#  ['953 ', 'Trash Day', 'Butch Walker and The Black Widows'],
#  ['954 ', 'Kiss Me', 'New Found Glory'],
#  ['955 ', 'Gravity', 'The Fold'],
#  ['956 ', 'Stay With Me', 'Benjy Davis Project'],
#  ['957 ', 'Beauty School', 'Deftones'],
#  ['958 ', 'Old Enough', 'The Raconteurs'],
#  ['959 ', 'You Got Yr. Cherry Bomb', 'Spoon'],
#  ['960 ', 'Whatever', 'Oasis'],
#  ['961 ', 'Lexington (Joey Pea-Pot With A Monkey Face)', 'Chiodos'],
#  ['962 ', 'Helena', 'My Chemical Romance'],
#  ['963 ', 'Fearless Love', 'Melissa Etheridge'],
#  ['964 ', 'Go On', 'Jack Johnson'],
#  ['965 ', 'When It Feels Good', 'Jeff Kashiwa'],
#  ['966 ', "Can't Let Go", 'Anthony Hamilton'],
#  ['967 ', 'Tijuana Dance', 'Rick Braun'],
#  ['968 ', 'Stop On By', 'Etta James'],
#  ['969 ', 'Love T.K.O.', 'Boz Scaggs'],
#  ['970 ', 'Clockwork', 'Alex De Grassi'],
#  ['971 ', 'Get Down On It', 'Wayman Tisdale'],
#  ['972 ', 'Winelite', 'Paul Brown'],
#  ['973 ', 'When 2 R 1', 'Dave Panico'],
#  ['974 ', 'How Lovely You Are', 'Najee'],
#  ['975 ', 'The Heart Of The Matter', 'India.Arie'],
#  ['976 ', 'Elephants On Ice Skates', 'Brian Bromberg'],
#  ['977 ', 'Uptown', 'Eric Marienthal'],
#  ['978 ', 'Hot House', 'Dizzy Gillespie'],
#  ['979 ', '52nd Street Theme', 'Dizzy Gillespie'],
#  ['980 ', 'Anthropology', 'Dizzy Gillespie'],
#  ['981 ', 'All The Things You Are', 'Dizzy Gillespie'],
#  ['982 ',
#   "Out Here Grindin' (w\\/ Akon, Rick Ross, Plies, Lil' Boosie, Trick Daddy & Lil Wayne)",
#   'DJ Khaled'],
#  ['983 ', 'Love Is All We Need', 'Mary J. Blige'],
#  ['984 ', 'Addiction (w\\/ Cassie)', 'Ryan Leslie'],
#  ['985 ', 'Sign Of A Victory (w\\/ Soweto Spiritual Singers)', 'R. Kelly'],
#  ['986 ', 'Spotlight', 'Jennifer Hudson'],
#  ['987 ', 'Everybody Knows', 'John Legend'],
#  ['988 ', 'No One', 'Alicia Keys'],
#  ['989 ', 'With You', 'Chris Brown'],
#  ['990 ', 'Last Chance', 'Ginuwine'],
#  ['991 ', "Swing (w\\/ Soulja Boy Tell 'Em)", 'Savage'],
#  ['992 ', 'Homecoming (w\\/ Chris Martin)', 'Kanye West'],
#  ['993 ', 'Why Just Be Friends', 'Joe'],
#  ['994 ', 'Amnesia', 'Cherish'],
#  ['995 ', 'Call On Me (w\\/ Nelly)', 'Janet Jackson'],
#  ['996 ', 'Let Me (Jill Scott & Will.I.am)', 'Sergio Mendes'],
#  ['997 ', 'Used To Be My Girl', 'Brian McKnight'],
#  ['998 ', 'Beat It 2008 (w\\/ Fergie)', 'Michael Jackson'],
#  ['999 ', 'Back 2 Eden', 'Donald Lawrence & Co.'],
#  ...]

# %% [markdown]
# ### Preparing the DataFrame

# %%
songs_df = pd.DataFrame(data=songs, columns=['id', 'title', 'artist'])
songs_df = songs_df.set_index('id')

# %% [markdown]
# ### Trainig the model
# - Each song is represented by a vector of dimension 32
# - We consider a window (context) of 20 songs before and after a song
# - Define 50 negative samples

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(
    playlists,
    vector_size=32,
    window=20,
    negative=50,
    min_count=1,
    workers=4
)

# %% [markdown]
# ### Testing the model

# %%
songs_df.iloc[2172]
# Out:
# title     Fade To Black
# artist        Metallica
# Name: 2172 , dtype: object

# %%
model.wv.most_similar(positive=str(2172))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 teste = model.wv.most_similar(positive=str(2172), topn=5)[:,0]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ### Checking the model response

# %%
import numpy as np

# %%
def print_recommendations(song_id):
    similar_songs = np.array(
        model.wv.most_similar(positive=str(song_id),topn=5)
    )[:,0]
    return songs_df.iloc[similar_songs]

# %%
print_recommendations(6)
# Out:
#                                                title                artist
# id
# 525                                         Rude Boy               Rihanna
# 420     Mo Money Mo Problems (w\/ Mase & Puff Daddy)  The Notorious B.I.G.
# 74         Letting Go (Dutty Love) (w\/ Nicki Minaj)         Sean Kingston
# 12205                               Give It Up To Me             Sean Paul
# 11961          Floor On Fire (w\/ Pitbull & Lil Jon)        Machel Montano
